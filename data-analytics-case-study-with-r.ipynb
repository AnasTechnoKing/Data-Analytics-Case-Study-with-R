# %% [markdown]
# # **Prepare Phase **

# %% [markdown]
# # **Downloading Data**

# %%
install.packages("tidyverse", lib = "/usr/lib/R/library")
install.packages("lubridate", lib = "/usr/lib/R/library")
install.packages("dplyr", lib = "/usr/lib/R/library")
install.packages("ggplot2", lib = "/usr/lib/R/library")
install.packages("tidyr", lib = "/usr/lib/R/library")
install.packages("here", lib = "/usr/lib/R/library")
install.packages("skimr", lib = "/usr/lib/R/library")
install.packages("janitor", lib = "/usr/lib/R/library")
# Out:
# Warning message in install.packages("dplyr", lib = "/usr/lib/R/library"):
# “installation of package ‘dplyr’ had non-zero exit status”

# %% [markdown]
# Loading packages on the R Script.

# %%
library(tidyverse)
library(lubridate)
library(dplyr)
library(ggplot2)
library(tidyr)
library(here)
library(skimr)
library(janitor)

# %% [markdown]
# # **Importing Dataset**

# %% [markdown]
# **dailyActivity_merged.csv**

# %%
Activity <- read.csv("dailyActivity_merged.csv")
# Out:
# Warning message in file(file, "rt"):
# “cannot open file 'dailyActivity_merged.csv': No such file or directory”
# Error in file(file, "rt"): cannot open the connection
# Traceback:
#
# 1. read.csv("dailyActivity_merged.csv")
# 2. read.table(file = file, header = header, sep = sep, quote = quote,
#  .     dec = dec, fill = fill, comment.char = comment.char, ...)
# 3. file(file, "rt")

# %%
head(Activity)

# %%
colnames(Activity)

# %%
str(Activity)

# %% [markdown]
# **dailyCalories_merged**

# %%
Calories <- read.csv("dailyCalories_merged.csv")

# %%
head(Calories)

# %%
colnames(Calories)

# %%
str(Calories)

# %% [markdown]
# **dailyIntensities_merged.csv**

# %%
Intensities <- read.csv("dailyIntensities_merged.csv")

# %%
head(Intensities)

# %%
colnames(Intensities)

# %%
str(Intensities)

# %% [markdown]
# **heartrate_seconds_merged.csv**

# %%
Heartrate <- read.csv("heartrate_seconds_merged.csv")

# %%
head(Heartrate)

# %%
colnames(Heartrate)

# %%
str(Heartrate)

# %% [markdown]
# **sleepDay_merged.csv**

# %%
Sleep <- read.csv("sleepDay_merged.csv")

# %%
head(Sleep)

# %%
colnames(Sleep)

# %%
str(Sleep)

# %% [markdown]
# **weightLogInfo_merged.csv**

# %%
Weight <- read.csv("weightLogInfo_merged.csv")

# %%
head(Weight)

# %%
colnames(Weight)

# %%
str(Weight)

# %% [markdown]
# > # **Process Phase **

# %% [markdown]
# **Cleaning & Formatting**

# %% [markdown]
# **dailyActivity_merged.csv**

# %%
Activity$ActivityDate=as.POSIXct(Activity$ActivityDate, format="%m/%d/%Y", tz=Sys.timezone())
Activity$date <- format(Activity$ActivityDate, format = "%m/%d/%y")
Activity$ActivityDate=as.Date(Activity$ActivityDate, format="%m/%d/%Y", tz=Sys.timezone())
Activity$date=as.Date(Activity$date, format="%m/%d/%Y")

# %% [markdown]
# **dailyIntensities_merged.csv**

# %%
Intensities$ActivityDay=as.Date(Intensities$ActivityDay, format="%m/%d/%Y", tz=Sys.timezone())

# %% [markdown]
# **sleepDay_merged.csv**

# %%
Sleep$SleepDay=as.POSIXct(Sleep$SleepDay, format="%m/%d/%Y %I:%M:%S %p", tz=Sys.timezone())
Sleep$date <- format(Sleep$SleepDay, format = "%m/%d/%y")
Sleep$date=as.Date(Sleep$date, "% m/% d/% y")

# %% [markdown]
# > # **Analyze Phase **

# %% [markdown]
# **Summarizing**

# %%
Activity %>%
summarise(Activity_participants = n_distinct(Activity$Id))

# %%
n_distinct(Calories$Id)

# %%
n_distinct(Intensities$Id)

# %%
n_distinct(Heartrate$Id)

# %%
n_distinct(Sleep$Id)

# %%
n_distinct(Weight$Id)

# %% [markdown]
# **Activity, Calories, Intensities, and Sleep.**

# %%
Activity %>%
    select(TotalSteps,
           TotalDistance,
           SedentaryMinutes, Calories) %>%
    summary()

# %%
Intensities %>%
  select(VeryActiveMinutes, FairlyActiveMinutes, LightlyActiveMinutes, SedentaryMinutes) %>%
  summary()

# %%
Calories %>%
  select(Calories) %>%
  summary()

# %%
Sleep %>%
  select(TotalSleepRecords, TotalMinutesAsleep, TotalTimeInBed) %>%
  summary()

# %%
Weight %>%
  select(WeightKg, Fat) %>%
  summary()

# %% [markdown]
# # **Data visualization (Share and Act Phases) **

# %% [markdown]
# **Relationship between Steps and Sedentary time**

# %%
ggplot(data=Activity, aes(x=TotalSteps, y=SedentaryMinutes)) + geom_point() + geom_smooth() + labs(title)

# %% [markdown]
# **Relationship between Minutes Asleep and Time in Bed**

# %%
ggplot(data=Sleep, aes(x=TotalMinutesAsleep, y=TotalTimeInBed)) + geom_point()+ geom_smooth() + labs(title)

# %% [markdown]
# **Relationship between Steps and Calories**

# %%
ggplot(data=Activity, aes(x=TotalSteps, y=Calories)) +geom_point() + geom_smooth() + labs(title="Total Steps vs. Calories")

# %% [markdown]
# **Intensities data**

# %%
Intensities$ActiveIntensity <- (Intensities$VeryActiveMinutes)/60

Combined_data <- merge(Weight, Intensities, by="Id", all=TRUE)
Combined_data$time <- format(Combined_data$Date, format = "%H:%M:%S")

ggplot(data=Combined_data, aes(x=time, y=ActiveIntensity)) + geom_histogram(stat = "identity", fill='dark red')theme(axis.text.x = element_text(angle = 90)) + labs(title="Total very Active Intensity vs. Time ")
